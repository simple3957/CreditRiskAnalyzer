# %% [markdown]
# <a href="https://colab.research.google.com/github/simple3957/CreditRiskAnalyzer/blob/main/CreditRiskAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy scikit-learn imbalanced-learn xgboost
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (0.1.3)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl (223.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 5.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nccl-cu12, xgboost
# Successfully installed nvidia-nccl-cu12-2.26.2 xgboost-2.1.4

# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
lending_data_df = pd.read_csv(
    Path('/content/sample_data/lending_data.csv')
)

# Review the DataFrame
display(lending_data_df.head())
display(lending_data_df.tail())
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt  loan_status
# 0                 1       22800            0
# 1                 0       13600            0
# 2                 0       16100            0
# 3                 1       22700            0
# 4                 1       23000            0
#        loan_size  interest_rate  borrower_income  debt_to_income  \
# 77531    19100.0         11.261            86600        0.653580
# 77532    17700.0         10.662            80900        0.629172
# 77533    17600.0         10.595            80300        0.626401
# 77534    16300.0         10.068            75300        0.601594
# 77535    15600.0          9.742            72300        0.585062
#
#        num_of_accounts  derogatory_marks  total_debt  loan_status
# 77531               12                 2       56600            1
# 77532               11                 2       50900            1
# 77533               11                 2       50300            1
# 77534               10                 2       45300            1
# 77535                9                 2       42300            1

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = lending_data_df['loan_status']

# Separate the X variable, the features
X = lending_data_df.drop(columns = 'loan_status')

# Review the y variable Series
display(y.head())
display(y.tail())

# Review the X variable DataFrame
display(X.head())
display(X.tail())
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: loan_status, dtype: int64
# 77531    1
# 77532    1
# 77533    1
# 77534    1
# 77535    1
# Name: loan_status, dtype: int64
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt
# 0                 1       22800
# 1                 0       13600
# 2                 0       16100
# 3                 1       22700
# 4                 1       23000
#        loan_size  interest_rate  borrower_income  debt_to_income  \
# 77531    19100.0         11.261            86600        0.653580
# 77532    17700.0         10.662            80900        0.629172
# 77533    17600.0         10.595            80300        0.626401
# 77534    16300.0         10.068            75300        0.601594
# 77535    15600.0          9.742            72300        0.585062
#
#        num_of_accounts  derogatory_marks  total_debt
# 77531               12                 2       56600
# 77532               11                 2       50900
# 77533               11                 2       50300
# 77534               10                 2       45300
# 77535                9                 2       42300

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# loan_status
# 0    75036
# 1     2500
# Name: count, dtype: int64

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state = 1
)

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
LR_model = LogisticRegression(random_state = 1)

# Fit the model using training data
LR_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
# Make a prediction using the testing data
LR_predictions = LR_model.predict(X_test)

# Print the balanced_accuracy score of the model
balanced_accuracy_score(y_test, LR_predictions)
# Out:
# 0.967989851522121

# %%
# Generate a confusion matrix for the model
'''
-- Out of the 18,765 loan status's that are healthy, the model predicted 18,663 as
   healthy correctly and 102 as healthy incorrectly

-- Out of the 619 loan status's that are non-healthy (high-risk), the model
   predicted 563 as non-healthy correctly and 56 as non-healthy incorrectly
'''

cm_imbalanced = confusion_matrix(y_test, LR_predictions)
cm_imbalanced_df = pd.DataFrame(cm_imbalanced,
                                index = ['Actual Healthy Loans (low-risk)',
                                'Actual Non-Healthy Loans (high-risk)'],
                                columns = ['Predicted Healthy Loans (low-risk)', 'Predicted Non-Healthy Loans (high-risk)']
                              )
cm_imbalanced_df
# Out:
#                                       Predicted Healthy Loans (low-risk)  \
# Actual Healthy Loans (low-risk)                                    18655
# Actual Non-Healthy Loans (high-risk)                                  36
#
#                                       Predicted Non-Healthy Loans (high-risk)
# Actual Healthy Loans (low-risk)                                           110
# Actual Non-Healthy Loans (high-risk)                                      583

# %%
# Print the classification report for the model
print(classification_report_imbalanced(y_test, LR_predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      0.99      0.94      1.00      0.97      0.94     18765
#           1       0.84      0.94      0.99      0.89      0.97      0.93       619
#
# avg / total       0.99      0.99      0.94      0.99      0.97      0.94     19384

# %%
# Import the RandomOverSampler module form imbalanced-learn
from imblearn.over_sampling import RandomOverSampler

# Instantiate the random oversampler model
# # Assign a random_state parameter of 1 to the model
ROS_model = RandomOverSampler(random_state = 1)

# Fit the original training data to the random_oversampler model
X_oversampled, y_oversampled = ROS_model.fit_resample(X_train, y_train)

# Count the distinct values of the resampled labels data
y_oversampled.value_counts()
# Out:
# loan_status
# 0    56271
# 1    56271
# Name: count, dtype: int64

# %%
# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
LR_oversampled_model = LogisticRegression(random_state = 1)

# Fit the model using the resampled training data
LR_oversampled_model.fit(X_oversampled, y_oversampled)

# Make a prediction using the testing data
LR_oversampled_pred = LR_oversampled_model.predict(X_test)

# Print the balanced_accuracy score of the model
balanced_accuracy_score(y_test, LR_oversampled_pred)
# Out:
# 0.9935981855334257

# %%
# Generate a confusion matrix for the model
'''
-- Out of the 18,765 loan status's that are healthy, the model predicted 18,649 as
   healthy correctly and 116 as healthy incorrectly

-- Out of the 619 loan status's that are non-healthy (high-risk), the model
   predicted 615 as non-healthy correctly and 4 as non-healthy incorrectly
'''

cm_oversampled = confusion_matrix(y_test, LR_oversampled_pred)
cm_oversampled_df = pd.DataFrame(cm_oversampled,
                                index = ['Actual Healthy Loans (low-risk)',
                                'Actual Non-Healthy Loans (high-risk)'],
                                columns = ['Predicted Healthy Loans (low-risk)', 'Predicted Non-Healthy Loans (high-risk)']
                              )
cm_oversampled_df
# Out:
#                                       Predicted Healthy Loans (low-risk)  \
# Actual Healthy Loans (low-risk)                                    18646
# Actual Non-Healthy Loans (high-risk)                                   4
#
#                                       Predicted Non-Healthy Loans (high-risk)
# Actual Healthy Loans (low-risk)                                           119
# Actual Non-Healthy Loans (high-risk)                                      615

# %%
# Print the classification report for the model
print(classification_report(y_test, LR_oversampled_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     18765
#            1       0.84      0.99      0.91       619
#
#     accuracy                           0.99     19384
#    macro avg       0.92      0.99      0.95     19384
# weighted avg       0.99      0.99      0.99     19384

# %%
# !pip install --upgrade xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.26.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.13.1)

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# ✅ Load dataset
file_path = "/content/sample_data/lending_data.csv"
df = pd.read_csv(file_path)

# ✅ Ensure column names have no spaces
df.columns = df.columns.str.strip()

# ✅ **Identify the target column: 'loan_status'**
target_col = 'loan_status'  # Directly specify the target column

# ✅ Extract target variable
y = df[target_col]
df.drop(columns=[target_col], inplace=True)

# ✅ Convert categorical variables using one-hot encoding
df = pd.get_dummies(df, drop_first=True)

# ✅ Reduce RAM usage by sampling (if dataset is large)
if df.shape[0] > 50000:
    df = df.sample(50000, random_state=42)
    y = y.loc[df.index]

# ✅ Split data
X_train, X_val, y_train, y_val = train_test_split(df, y, test_size=0.2, random_state=42, stratify=y)

# ✅ Handle class imbalance using SMOTE
smote = SMOTE(random_state=42, sampling_strategy=0.5)  # Prevent excessive duplication
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# ✅ Scale numerical features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_val_scaled = scaler.transform(X_val)

# ✅ Define XGBoost Model with Optimized Parameters
xgb_model = xgb.XGBClassifier(
    objective="binary:logistic",  # Changed for binary classification
    eval_metric="logloss",        # Changed for binary classification
    n_estimators=200,  # Reduce estimators
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    tree_method="hist"  # Optimized for speed
)

# ✅ Train model with early stopping
# Pass early_stopping_rounds to the eval_set
eval_set = [(X_val_scaled, y_val)]
xgb_model.fit(
    X_train_scaled,
    y_train_resampled,
    eval_set=eval_set,
    verbose=True
)

# ✅ Predictions & Evaluation
y_pred = xgb_model.predict(X_val_scaled)
y_prob = xgb_model.predict_proba(X_val_scaled)[:, 1]  # Probability for positive class

accuracy = accuracy_score(y_val, y_pred)
roc_auc = roc_auc_score(y_val, y_prob)  # ROC-AUC for binary classification

print(f"Accuracy: {accuracy:.5f}")
print(f"ROC-AUC Score: {roc_auc}")
print("Classification Report:\n", classification_report(y_val, y_pred))
# Out:
# [0]	validation_0-logloss:0.38349
# [1]	validation_0-logloss:0.33967
# [2]	validation_0-logloss:0.30213
# [3]	validation_0-logloss:0.26969
# [4]	validation_0-logloss:0.24150
# [5]	validation_0-logloss:0.21687
# [6]	validation_0-logloss:0.19524
# [7]	validation_0-logloss:0.17625
# [8]	validation_0-logloss:0.15947
# [9]	validation_0-logloss:0.14465
# [10]	validation_0-logloss:0.13151
# [11]	validation_0-logloss:0.11987
# [12]	validation_0-logloss:0.10953
# [13]	validation_0-logloss:0.10033
# [14]	validation_0-logloss:0.09214
# [15]	validation_0-logloss:0.08485
# [16]	validation_0-logloss:0.07839
# [17]	validation_0-logloss:0.07261
# [18]	validation_0-logloss:0.06748
# [19]	validation_0-logloss:0.06293
# [20]	validation_0-logloss:0.05884
# [21]	validation_0-logloss:0.05522
# [22]	validation_0-logloss:0.05200
# [23]	validation_0-logloss:0.04914
# [24]	validation_0-logloss:0.04661
# [25]	validation_0-logloss:0.04437
# [26]	validation_0-logloss:0.04239
# [27]	validation_0-logloss:0.04064
# [28]	validation_0-logloss:0.03908
# [29]	validation_0-logloss:0.03771
# [30]	validation_0-logloss:0.03651
# [31]	validation_0-logloss:0.03546
# [32]	validation_0-logloss:0.03454
# [33]	validation_0-logloss:0.03371
# [34]	validation_0-logloss:0.03300
# [35]	validation_0-logloss:0.03236
# [36]	validation_0-logloss:0.03179
# [37]	validation_0-logloss:0.03133
# [38]	validation_0-logloss:0.03094
# [39]	validation_0-logloss:0.03059
# [40]	validation_0-logloss:0.03030
# [41]	validation_0-logloss:0.03003
# [42]	validation_0-logloss:0.02978
# [43]	validation_0-logloss:0.02957
# [44]	validation_0-logloss:0.02937
# [45]	validation_0-logloss:0.02924
# [46]	validation_0-logloss:0.02907
# [47]	validation_0-logloss:0.02898
# [48]	validation_0-logloss:0.02894
# [49]	validation_0-logloss:0.02888
# [50]	validation_0-logloss:0.02881
# [51]	validation_0-logloss:0.02876
# [52]	validation_0-logloss:0.02875
# [53]	validation_0-logloss:0.02874
# [54]	validation_0-logloss:0.02872
# [55]	validation_0-logloss:0.02869
# [56]	validation_0-logloss:0.02865
# [57]	validation_0-logloss:0.02870
# [58]	validation_0-logloss:0.02869
# [59]	validation_0-logloss:0.02867
# [60]	validation_0-logloss:0.02870
# [61]	validation_0-logloss:0.02873
# [62]	validation_0-logloss:0.02872
# [63]	validation_0-logloss:0.02866
# [64]	validation_0-logloss:0.02863
# [65]	validation_0-logloss:0.02860
# [66]	validation_0-logloss:0.02856
# [67]	validation_0-logloss:0.02856
# [68]	validation_0-logloss:0.02857
# [69]	validation_0-logloss:0.02853
# [70]	validation_0-logloss:0.02850
# [71]	validation_0-logloss:0.02846
# [72]	validation_0-logloss:0.02845
# [73]	validation_0-logloss:0.02844
# [74]	validation_0-logloss:0.02846
# [75]	validation_0-logloss:0.02844
# [76]	validation_0-logloss:0.02843
# [77]	validation_0-logloss:0.02841
# [78]	validation_0-logloss:0.02839
# [79]	validation_0-logloss:0.02835
# [80]	validation_0-logloss:0.02836
# [81]	validation_0-logloss:0.02836
# [82]	validation_0-logloss:0.02836
# [83]	validation_0-logloss:0.02835
# [84]	validation_0-logloss:0.02834
# [85]	validation_0-logloss:0.02832
# [86]	validation_0-logloss:0.02833
# [87]	validation_0-logloss:0.02836
# [88]	validation_0-logloss:0.02838
# [89]	validation_0-logloss:0.02839
# [90]	validation_0-logloss:0.02837
# [91]	validation_0-logloss:0.02836
# [92]	validation_0-logloss:0.02843
# [93]	validation_0-logloss:0.02848
# [94]	validation_0-logloss:0.02849
# [95]	validation_0-logloss:0.02849
# [96]	validation_0-logloss:0.02847
# [97]	validation_0-logloss:0.02846
# [98]	validation_0-logloss:0.02849
# [99]	validation_0-logloss:0.02848
# [100]	validation_0-logloss:0.02844
# [101]	validation_0-logloss:0.02843
# [102]	validation_0-logloss:0.02844
# [103]	validation_0-logloss:0.02842
# [104]	validation_0-logloss:0.02842
# [105]	validation_0-logloss:0.02841
# [106]	validation_0-logloss:0.02845
# [107]	validation_0-logloss:0.02842
# [108]	validation_0-logloss:0.02840
# [109]	validation_0-logloss:0.02844
# [110]	validation_0-logloss:0.02841
# [111]	validation_0-logloss:0.02841
# [112]	validation_0-logloss:0.02841
# [113]	validation_0-logloss:0.02843
# [114]	validation_0-logloss:0.02843
# [115]	validation_0-logloss:0.02845
# [116]	validation_0-logloss:0.02847
# [117]	validation_0-logloss:0.02846
# [118]	validation_0-logloss:0.02850
# [119]	validation_0-logloss:0.02847
# [120]	validation_0-logloss:0.02847
# [121]	validation_0-logloss:0.02845
# [122]	validation_0-logloss:0.02845
# [123]	validation_0-logloss:0.02853
# [124]	validation_0-logloss:0.02851
# [125]	validation_0-logloss:0.02854
# [126]	validation_0-logloss:0.02855
# [127]	validation_0-logloss:0.02856
# [128]	validation_0-logloss:0.02860
# [129]	validation_0-logloss:0.02856
# [130]	validation_0-logloss:0.02861
# [131]	validation_0-logloss:0.02862
# [132]	validation_0-logloss:0.02861
# [133]	validation_0-logloss:0.02865
# [134]	validation_0-logloss:0.02868
# [135]	validation_0-logloss:0.02870
# [136]	validation_0-logloss:0.02869
# [137]	validation_0-logloss:0.02865
# [138]	validation_0-logloss:0.02869
# [139]	validation_0-logloss:0.02869
# [140]	validation_0-logloss:0.02865
# [141]	validation_0-logloss:0.02866
# [142]	validation_0-logloss:0.02864
# [143]	validation_0-logloss:0.02859
# [144]	validation_0-logloss:0.02856
# [145]	validation_0-logloss:0.02857
# [146]	validation_0-logloss:0.02856
# [147]	validation_0-logloss:0.02856
# [148]	validation_0-logloss:0.02855
# [149]	validation_0-logloss:0.02858
# [150]	validation_0-logloss:0.02858
# [151]	validation_0-logloss:0.02857
# [152]	validation_0-logloss:0.02861
# [153]	validation_0-logloss:0.02861
# [154]	validation_0-logloss:0.02859
# [155]	validation_0-logloss:0.02860
# [156]	validation_0-logloss:0.02863
# [157]	validation_0-logloss:0.02866
# [158]	validation_0-logloss:0.02866
# [159]	validation_0-logloss:0.02865
# [160]	validation_0-logloss:0.02868
# [161]	validation_0-logloss:0.02867
# [162]	validation_0-logloss:0.02867
# [163]	validation_0-logloss:0.02864
# [164]	validation_0-logloss:0.02867
# [165]	validation_0-logloss:0.02868
# [166]	validation_0-logloss:0.02871
# [167]	validation_0-logloss:0.02870
# [168]	validation_0-logloss:0.02871
# [169]	validation_0-logloss:0.02872
# [170]	validation_0-logloss:0.02869
# [171]	validation_0-logloss:0.02873
# [172]	validation_0-logloss:0.02873
# [173]	validation_0-logloss:0.02873
# [174]	validation_0-logloss:0.02877
# [175]	validation_0-logloss:0.02875
# [176]	validation_0-logloss:0.02874
# [177]	validation_0-logloss:0.02874
# [178]	validation_0-logloss:0.02876
# [179]	validation_0-logloss:0.02880
# [180]	validation_0-logloss:0.02882
# [181]	validation_0-logloss:0.02883
# [182]	validation_0-logloss:0.02882
# [183]	validation_0-logloss:0.02882
# [184]	validation_0-logloss:0.02883
# [185]	validation_0-logloss:0.02882
# [186]	validation_0-logloss:0.02879
# [187]	validation_0-logloss:0.02879
# [188]	validation_0-logloss:0.02882
# [189]	validation_0-logloss:0.02880
# [190]	validation_0-logloss:0.02881
# [191]	validation_0-logloss:0.02882
# [192]	validation_0-logloss:0.02881
# [193]	validation_0-logloss:0.02883
# [194]	validation_0-logloss:0.02887
# [195]	validation_0-logloss:0.02886
# [196]	validation_0-logloss:0.02884
# [197]	validation_0-logloss:0.02880
# [198]	validation_0-logloss:0.02881
# [199]	validation_0-logloss:0.02880
# Accuracy: 0.99420
# ROC-AUC Score: 0.9960779626777633
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      9686
#            1       0.85      0.99      0.91       314
#
#     accuracy                           0.99     10000
#    macro avg       0.92      0.99      0.96     10000
# weighted avg       0.99      0.99      0.99     10000
